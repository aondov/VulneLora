# %%
# %matplotlib inline
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics
from IPython.display import set_matplotlib_formats
from filter import *

# set_matplotlib_formats('svg')
pd.set_option('display.max_rows', None)
cut_ratio = 0.05

# %%
print("\n##### APs TABLE #####\n")
file = "aps.csv"
data = pd.read_csv(file, delimiter=',')

### FILTERING ###
enable_filtering = False

config = {
    'id': [],
    'lora_protocol': [],
    'dev_id': []
}
operator = "AND"
### FILTERING ###

filtered_data = filter(data, config, enable_filtering, operator)

del filtered_data['protocol_ver']
del filtered_data['max_power']
del filtered_data['channels_num']
del filtered_data['duty_cycle_refresh']
del filtered_data['transmission_param_id']
del filtered_data['stat_model']
del filtered_data['name']
del filtered_data['firmware']
del filtered_data['lat']
del filtered_data['lng']
del filtered_data['antena_gain']
del filtered_data['lora_protocol_ver']
                
display(filtered_data)
# Out:
# ##### APs TABLE #####
#           id lora_protocol  dev_id
# 0     111111     LoRa@FIIT       1
# 1     123456     LoRa@FIIT       2
# 2       3333     Lora@FIIT       3
# 3     555555     LoRa@FIIT       4
# 4       9999     LoRa@FIIT       5
# 5      55117     LoRa@FIIT       6
# 6      95876     LoRa@FIIT       7
# 7      55817     LoRa@FIIT       8
# 8      18531     LoRa@FIIT       9
# 9      89623     LoRa@FIIT      10
# 10     11377     LoRa@FIIT      11
# 11     53673     LoRa@FIIT      12
# 12     23123     LoRa@FIIT      13
# 13     23279     LoRa@FIIT      14
# 14     99781     LoRa@FIIT      15
# 15     24809     LoRa@FIIT      16
# 16     42657     LoRa@FIIT      17
# 17     27117     LoRa@FIIT      18
# 18     33044     LoRa@FIIT      19
# 19     61638     LoRa@FIIT      20
# 20     70640     LoRa@FIIT      21
# 21     95233     LoRa@FIIT      22
# 22     88457     LoRa@FIIT      23
# 23     99969     LoRa@FIIT      24
# 24     69772     LoRa@FIIT      25
# ...
