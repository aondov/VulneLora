# %%
# %matplotlib inline
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics
from IPython.display import set_matplotlib_formats
from filter import *

# set_matplotlib_formats('svg')
pd.set_option('display.max_rows', None)
cut_ratio = 0.05

# %%
print("\n##### UPLINK MESSAGES #####\n")
file = "uplink_messages.csv"
data = pd.read_csv(file, delimiter=',')

### FILTERING ###
enable_filtering = True

config = {
    'id': [669, 668, 667],
    'node_id': [],
    'ap_id': [],
    'snr': [],
    'rssi': [],
    'spf': [],
    'frequency': [],
    'app_data': [],
    'recv_time_from': "",
    'recv_time_to': ""
}
operator = "OR"
### FILTERING ###

filtered_data = filter(data, config, enable_filtering, operator)

del filtered_data['msg_group_number']
del filtered_data['is_primary']
del filtered_data['message_type_id']
del filtered_data['coderate']
del filtered_data['bandwidth']
del filtered_data['duty_cycle_remaining']
del filtered_data['seq']
del filtered_data['power']
del filtered_data['airtime']
del filtered_data['application_id']
del filtered_data['battery']
del filtered_data['dev_id']
                
sorted_data = filtered_data.sort_values(by='receive_time', ascending=True)
display(sorted_data)
# Out:
# ##### UPLINK MESSAGES #####
#       id                                           app_data    snr   rssi  \
# 637  667                                           dGVzdAA=   9.50  -33.0
# 638  668                                           dGVzdAA=   7.25  -35.0
# 639  669  '; INSERT INTO users (id, user_name, password)... -18.90 -101.8
#
#                 receive_time  frequency  spf   ap_id node_id
# 637  2024-05-01 12:24:24.928  866100000    7    3333    IiIi
# 638   2024-05-01 12:24:35.95  866500000    7    3333    IiIi
# 639  2024-05-01 12:24:43.386  866100000    7  123456    1Rmh

# %%
print("\n##### USERS TABLE #####\n")
file = "users.csv"
data = pd.read_csv(file, delimiter=',')

### FILTERING ###
enable_filtering = False

config = {
    'id': [],
    'user_name': [],
    'password': []
}
operator = "AND"
### FILTERING ###

filtered_data = filter(data, config, enable_filtering, operator)

display(filtered_data)
# Out:
# ##### USERS TABLE #####
#    id user_name                                           password
# 0   1     admin  $2a$10$gHsd/1AXl7Q4Gr4nBxk.uew3SfQ2hsiMDz5Y3Y/...
